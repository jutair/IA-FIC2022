# %%
import numpy as np
import pandas as pd
import matplotlib as mt
import seaborn as sns
import plotly as pl

# %%
with open('penguins_size.csv', 'r') as f:
    a = f.read()

# %%
df= pd.read_csv('penguins_size.csv')

# %%
df.head(1)
# mostra os 20 primeiros dados
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
#
#    body_mass_g   sex
# 0       3750.0  MALE

# %%
df['body_mass_g'].mean() #Média da massa
# Out:
# 4201.754385964912

# %%
df.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %%
df.species.unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
df.sex.unique()
# Out:
# array(['MALE', 'FEMALE', nan, '.'], dtype=object)

# %%
df.dropna()
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 4    Adelie  Torgersen              36.7             19.3              193.0
# 5    Adelie  Torgersen              39.3             20.6              190.0
# ..      ...        ...               ...              ...                ...
# 338  Gentoo     Biscoe              47.2             13.7              214.0
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 4         3450.0  FEMALE
# 5         3650.0    MALE
# ..           ...     ...
# 338       4925.0  FEMALE
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE
#
# [334 rows x 7 columns]

# %%
df.tail()
# Out:
#     species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 339  Gentoo  Biscoe               NaN              NaN                NaN
# 340  Gentoo  Biscoe              46.8             14.3              215.0
# 341  Gentoo  Biscoe              50.4             15.7              222.0
# 342  Gentoo  Biscoe              45.2             14.8              212.0
# 343  Gentoo  Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# 339          NaN     NaN
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE

# %%
df.dropna(inplace= True)

# %%
df.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        334.000000       334.000000         334.000000   334.000000
# mean          43.994311        17.160479         201.014970  4209.056886
# std            5.460521         1.967909          14.022175   804.836129
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.500000        15.600000         190.000000  3550.000000
# 50%           44.500000        17.300000         197.000000  4050.000000
# 75%           48.575000        18.700000         213.000000  4793.750000
# max           59.600000        21.500000         231.000000  6300.000000

# %%
df = df[df.sex != '.']

# %%
df.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        333.000000       333.000000         333.000000   333.000000
# mean          43.992793        17.164865         200.966967  4207.057057
# std            5.468668         1.969235          14.015765   805.215802
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.500000        15.600000         190.000000  3550.000000
# 50%           44.500000        17.300000         197.000000  4050.000000
# 75%           48.600000        18.700000         213.000000  4775.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %%
sns.pairplot(df)

# %%
df.query('sex == "MALE"')
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 5    Adelie  Torgersen              39.3             20.6              190.0
# 7    Adelie  Torgersen              39.2             19.6              195.0
# 13   Adelie  Torgersen              38.6             21.2              191.0
# 14   Adelie  Torgersen              34.6             21.1              198.0
# ..      ...        ...               ...              ...                ...
# 333  Gentoo     Biscoe              51.5             16.3              230.0
# 335  Gentoo     Biscoe              55.1             16.0              230.0
# 337  Gentoo     Biscoe              48.8             16.2              222.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g   sex
# 0         3750.0  MALE
# 5         3650.0  MALE
# 7         4675.0  MALE
# 13        3800.0  MALE
# 14        4400.0  MALE
# ..           ...   ...
# 333       5500.0  MALE
# 335       5850.0  MALE
# 337       6000.0  MALE
# 341       5750.0  MALE
# 343       5400.0  MALE
#
# [168 rows x 7 columns]

# %%
massa = df.body_mass_g.to_numpy()

# %%
type(massa)
# Out:
# numpy.ndarray

# %%
massa.max()
# Out:
# 6300.0

# %%
massa[231]
# Out:
# 6300.0

# %%
massa[0:10]
# Out:
# array([3750., 3800., 3250., 3450., 3650., 3625., 4675., 3200., 3800.,
#        4400.])

# %%
a =np.ones(4)

# %%
a
# Out:
# array([1., 1., 1., 1.])

# %%
b = 30+10*np.random.random((6, 6))

# %%
print (b)
# Out:
# [[31.02113572 34.96417393 37.28114959 37.05128152 30.86288613 34.70587143]
#  [33.98582398 32.06619525 39.11497332 39.00562308 39.83242267 31.08327203]
#  [33.85453956 38.89618053 37.44343752 30.66796321 34.6214788  39.60812511]
#  [36.36656118 30.97634668 36.32053264 39.6008939  30.89062736 30.62102245]
#  [38.972911   32.96974617 39.67321847 34.24107363 32.76958436 32.49569552]
#  [35.31176129 33.1638873  39.52819788 31.03987849 33.74085046 36.60586439]]

# %%
b[2:5, 2:4]
# Out:
# array([[37.44343752, 30.66796321],
#        [36.32053264, 39.6008939 ],
#        [39.67321847, 34.24107363]])
